# %%
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim

# Load data
data = np.load("ising_2d_dataset_3x3.npz")
spin_configs = data["spin_configs"]         
psi_squared_true = data["psi_squared"]      

psi_squared_true /= psi_squared_true.sum()

# Convert to tensors
X = torch.tensor(spin_configs, dtype=torch.float32)
y_true = torch.tensor(psi_squared_true, dtype=torch.float32).unsqueeze(1) 

class PINN(nn.Module):
    def __init__(self, input_dim):
        super(PINN, self).__init__()
        self.net = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 128),
            nn.ReLU(),
            nn.Linear(128, 1),
            nn.Softplus() 
        )

    def forward(self, x):
        out = self.net(x)
        return out

def ising_energy(spins, J=1.0):

    batch_size = spins.shape[0]
    spins_2d = spins.view(batch_size, 3, 3)  # Reshape to 3x3 lattice

    energy = torch.zeros(batch_size, dtype=torch.float32)

    for i in range(3):
        for j in range(3):
            s = spins_2d[:, i, j]
            if i < 2:
                energy -= J * s * spins_2d[:, i + 1, j]  # Vertical neighbors
            if j < 2:
                energy -= J * s * spins_2d[:, i, j + 1]  # Horizontal neighbors

    return energy.unsqueeze(1)  # Shape [batch_size, 1]



def physics_loss(prob_pred, energies, true_ground_energy):

    exp_energy = torch.sum(prob_pred * energies)
    return (exp_energy - true_ground_energy) ** 2

from scipy import sparse
from scipy.sparse.linalg import eigsh

def get_ground_state_energy_2d(J=1.0, h=1.0):
    n_spins = 9
    dim = 2 ** n_spins
    H = sparse.lil_matrix((dim, dim))

    for idx in range(dim):
        config = [int(x) for x in format(idx, '09b')]
        spin_config = [1 if s == 0 else -1 for s in config]

        diag_term = 0
        for i in range(3):
            for j in range(3):
                idx_1d = i * 3 + j
                if i < 2:
                    idx_down = (i + 1) * 3 + j
                    diag_term -= J * spin_config[idx_1d] * spin_config[idx_down]
                if j < 2:
                    idx_right = i * 3 + (j + 1)
                    diag_term -= J * spin_config[idx_1d] * spin_config[idx_right]
        H[idx, idx] = diag_term

        for i in range(n_spins):
            new_config = config.copy()
            new_config[i] = 1 - new_config[i]
            new_idx = int(''.join(map(str, new_config)), 2)
            H[idx, new_idx] = -h

    H_csr = H.tocsr()
    eigenvalues, _ = eigsh(H_csr, k=1, which='SA')
    return float(eigenvalues[0])

# %%
E0 = get_ground_state_energy_2d(J=1.0, h=1.0)
E0 = torch.tensor(E0, dtype=torch.float32)

model = PINN(input_dim=X.shape[1])
optimizer = optim.Adam(model.parameters(), lr=1e-3)
epochs = 1000
lambda_phys = 0.3 
loss_log = {
    "total": [],
    "mse": [],
    "phys": []
}

for epoch in range(epochs):
    model.train()
    optimizer.zero_grad()
    
    y_pred = model(X)
    y_pred_norm = y_pred / torch.sum(y_pred)

    mse_loss = nn.MSELoss()(y_pred_norm, y_true)

    energies = ising_energy(X)
    phys_loss = physics_loss(y_pred_norm, energies, E0)

    scale_factor = mse_loss.item() / (phys_loss.item() + 1e-8)
    phys_loss_scaled = phys_loss * scale_factor

    total_loss = lambda_phys * phys_loss_scaled + (1 - lambda_phys) * mse_loss

    loss_log["total"].append(total_loss.item())
    loss_log["mse"].append(mse_loss.item())
    loss_log["phys"].append(phys_loss.item())  

    total_loss.backward()
    optimizer.step()

    if epoch % 100 == 0:
        print(f"Epoch {epoch}: Total Loss = {total_loss.item():.6f}, MSE = {mse_loss.item():.6f}, Physics = {phys_loss.item():.6f} (Scale={scale_factor:.4e})")

print("Final logged losses:")
print(loss_log)
# Out:
# Epoch 0: Total Loss = 0.000433, MSE = 0.000433, Physics = 190.495865 (Scale=2.2744e-06)
# Epoch 100: Total Loss = 0.000003, MSE = 0.000003, Physics = 19.654284 (Scale=1.7077e-07)
# Epoch 200: Total Loss = 0.000001, MSE = 0.000001, Physics = 17.061754 (Scale=3.8075e-08)
# Epoch 300: Total Loss = 0.000000, MSE = 0.000000, Physics = 15.427022 (Scale=9.5762e-09)
# Epoch 400: Total Loss = 0.000000, MSE = 0.000000, Physics = 14.945206 (Scale=3.8487e-09)
# Epoch 500: Total Loss = 0.000000, MSE = 0.000000, Physics = 14.679596 (Scale=2.3739e-09)
# Epoch 600: Total Loss = 0.000000, MSE = 0.000000, Physics = 14.542269 (Scale=1.9607e-09)
# Epoch 700: Total Loss = 0.000000, MSE = 0.000000, Physics = 14.472999 (Scale=1.7956e-09)
# Epoch 800: Total Loss = 0.000000, MSE = 0.000000, Physics = 14.436733 (Scale=1.6975e-09)
# Epoch 900: Total Loss = 0.000000, MSE = 0.000000, Physics = 14.417100 (Scale=1.6172e-09)
# Final logged losses:
# {'total': [0.00043325533624738455, 0.0004329249495640397, 0.0004325874615460634, 0.00043223495595157146, 0.00043186487164348364, 0.00043148110853508115, 0.00043107790406793356, 0.0004306535702198744, 0.0004302049055695534, 0.0004297226550988853, 0.0004292009980417788, 0.00042863591806963086, 0.0004280120774637908, 0.0004273268859833479, 0.00042656532605178654, 0.0004257172695361078, 0.00042477570241317153, 0.0004237399552948773, 0.000422608049120754, 0.0004213367938064039, 0.000419918040279299, 0.00041833543218672276, 0.0004165584105066955, 0.0004145572311244905, 0.0004123144317418337, 0.00040978699689731, 0.0004069579881615937, 0.0004037676262669265, 0.00040013203397393227, 0.0003959733294323087, 0.00039119686698541045, 0.0003857199917547405, 0.00037934683496132493, 0.0003719110391102731, 0.00036312974407337606, 0.00035269989166408777, 0.00034017337020486593, 0.00032499575172550976, 0.00030650512780994177, 0.0002838935179170221, 0.00025651900796219707, 0.00022437269217334688, 0.00018861988792195916, 0.00015154320863075554, 0.00011529406765475869, 8.141206490108743e-05, 5.0943668611580506e-05, 2.7121539460495114e-05, 1.1883850675076246e-05, 3.852603185805492e-06, 4.589618583850097e-06, 7.349094630626496e-06, 1.4654156984761357e-05, 2.0634415704989806e-05, 2.416949428152293e-05, 2.9390219424385577e-05, 3.2743460906203836e-05, 3.237115379306488e-05, 3.263530015829019e-05, 3.314467176096514e-05, 3.0378447263501585e-05, 2.7171870897291228e-05, 2.512096216378268e-05, 2.0704073904198594e-05, 1.6055942978709936e-05, 1.2903231436212081e-05, 8.449432243651245e-06, 5.8965156313206535e-06, 4.667987468565116e-06, 4.288671334506944e-06, 5.914783287153114e-06, 7.13924782758113e-06, 8.68969891598681e-06, 8.703229468665086e-06, 8.323317160829902e-06, 6.797154128435068e-06, 5.654019332723692e-06, 4.419491688167909e-06, 4.086370609002188e-06, 3.876706159644527e-06, 4.259022716723848e-06, 4.666865606850479e-06, 5.021630386181641e-06, 5.418537512014154e-06, 5.429171324067283e-06, 5.489946488523856e-06, 5.212006271904102e-06, 4.886127499048598e-06, 4.562505637295544e-06, 4.112685473955935e-06, 3.853584075841354e-06, 3.5781440601567738e-06, 3.489930350042414e-06, 3.445453103267937e-06, 3.478574853943428e-06, 3.563844529708149e-06, 3.5842681427311618e-06, 3.613158241932979e-06, 3.545067102095345e-06, 3.4857082482631085e-06, 3.3562955650268123e-06, 3.261637402829365e-06, 3.177338840032462e-06, 3.1184354156721383e-06, 3.1014826618047664e-06, 3.088201765422127e-06, 3.110990292043425e-06, 3.1059385037224274e-06, 3.1033134746394353e-06, 3.084871877945261e-06, 3.0352337034855736e-06, 2.9829425329808146e-06, 2.9096145226503722e-06, 2.840386969182873e-06, 2.7689661692420486e-06, 2.7032408524974016e-06, 2.6565746793494327e-06, 2.611411673569819e-06, 2.5793171971599804e-06, 2.5509380066068843e-06, 2.518783730920404e-06, 2.4873725124052726e-06, 2.4496866899426095e-06, 2.4118244255078025e-06, 2.3709094421064947e-06, 2.3313357360166265e-06, 2.297096443726332e-06, 2.2627950784226414e-06, 2.2335593712341506e-06, 2.2061701656639343e-06, 2.1775110781163676e-06, 2.1490925519174198e-06, 2.1179478153499076e-06, 2.0850777673331322e-06, 2.0504603526205756e-06, 2.014556457652361e-06, 1.9795354546658928e-06, 1.94425319932634e-06, 1.9109043023490813e-06, 1.8799976260197582e-06, 1.849881982707302e-06, 1.821938894863706e-06, 1.7952588677871972e-06, 1.7688855677988613e-06, 1.743431312206667e-06, 1.7183351701532956e-06, 1.6936699012148893e-06, 1.669480752752861e-06, 1.6459814560221275e-06, 1.6233886981353862e-06, 1.6011606476240559e-06, 1.5796497336850734e-06, 1.558828216730035e-06, 1.5377966064988868e-06, 1.5168105846896651e-06, 1.495737706136424e-06, 1.474129021517001e-06, 1.4523556046697195e-06, 1.430422457815439e-06, 1.4084396298130741e-06, 1.3865237633581273e-06, 1.3646847492054803e-06, 1.3429516911855899e-06, 1.3213779084253474e-06, 1.2999844329897314e-06, 1.278767967960448e-06, 1.2576368817462935e-06, 1.2366921282591647e-06, 1.2159226798758027e-06, 1.1952281511184992e-06 ...

# %%
import matplotlib.pyplot as plt
model.eval()
with torch.no_grad():
    y_pred = model(X)
    y_pred_norm = y_pred / torch.sum(y_pred)

y_pred_np = y_pred_norm.squeeze().numpy()
y_true_np = y_true.squeeze().numpy()

print(y_pred_np)
print(y_true_np)

plt.figure(figsize=(10, 5))
plt.plot(y_true_np, label="True $\psi^2$", marker='o', linestyle='none', alpha=0.6)
plt.plot(y_pred_np, label="Predicted $\psi^2$", marker='x', linestyle='none', alpha=0.6)
plt.xlabel("Configuration Index")
plt.ylabel("Probability")
plt.title("True vs Predicted Probability Distribution")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [3.31304014e-01 2.07418613e-02 1.00267706e-02 1.27461692e-03
#  2.07184199e-02 7.75632274e-04 6.83978549e-04 1.44988124e-04
#  9.93303582e-03 1.64771429e-03 1.49853615e-04 5.16326036e-05
#  2.63819908e-04 6.29722563e-05 2.21207083e-05 3.49148031e-05
#  5.31315384e-03 1.41506913e-04 3.66619672e-04 3.89853376e-05
#  2.68558244e-04 2.65047202e-05 1.36977877e-04 2.65914805e-05
#  6.69008936e-04 9.82178099e-05 5.34543869e-05 4.38683346e-05
#  9.33634801e-05 2.74529084e-05 4.47033672e-05 3.75939198e-05
#  9.99415200e-03 2.89941789e-04 2.43893504e-04 4.71225649e-05
#  1.11953123e-03 5.05537791e-05 1.04706989e-04 5.72087847e-05
#  3.62458813e-04 8.60869259e-05 4.91740066e-05 3.62370556e-05
#  6.38401470e-05 4.94570522e-05 3.44061082e-05 6.75644696e-05
#  1.27299718e-04 1.88665490e-05 4.23806196e-05 1.70899220e-05
#  7.24177953e-05 1.95177545e-05 8.70961012e-05 4.13944654e-05
#  7.87381941e-05 4.14534043e-05 4.84203956e-05 5.12851948e-05
#  1.18365031e-04 4.96435423e-05 8.76415797e-05 2.55190418e-04
#  2.06906870e-02 9.62530612e-04 1.43269441e-04 4.34397807e-05
#  1.61843072e-03 1.72695887e-04 3.36054982e-05 2.84453490e-05
#  1.20502326e-03 4.92221327e-04 2.53709586e-05 2.47278895e-05
#  1.39334064e-04 1.23934253e-04 1.52571565e-05 3.89833294e-05
#  2.31139958e-04 2.25468684e-05 2.75237126e-05 9.08985839e-06
#  6.54064643e-05 2.44201783e-05 1.55616726e-05 1.57443064e-05
#  1.51454748e-04 6.16346588e-05 3.07131922e-05 2.93799712e-05
#  1.09761560e-04 7.37067239e-05 4.67756036e-05 1.10926871e-04
#  3.50271002e-04 2.93726007e-05 1.22125266e-05 1.17613972e-05
#  1.30690110e-04 4.45155601e-05 2.27171531e-05 3.22030064e-05
#  1.02984282e-04 5.94111734e-05 2.42399256e-05 3.09356474e-05
#  5.94856574e-05 1.01306861e-04 4.05950232e-05 9.85257793e-05
#  2.52106238e-05 1.38489058e-05 1.05453410e-05 8.08702680e-06
#  3.84111481e-05 1.76429057e-05 3.13848068e-05 4.05081701e-05
#  5.71124765e-05 4.72266584e-05 2.80697441e-05 5.91190073e-05
#  1.61436037e-04 1.13424845e-04 1.21702229e-04 1.20949431e-03
#  1.00118835e-02 5.65061055e-04 3.73454095e-04 1.37016337e-04
#  2.27999379e-04 4.86949721e-05 3.57422759e-05 3.49670845e-05
#  3.38223443e-04 1.53603760e-04 2.68077983e-05 6.69548754e-05
#  4.19945027e-05 3.80347046e-05 1.52275616e-05 2.61566074e-05
#  1.57835035e-04 2.22794006e-05 5.53293503e-05 4.07435946e-05
#  2.59051467e-05 1.36174031e-05 2.82244036e-05 3.37379824e-05
#  1.08615954e-04 8.91266827e-05 4.51608321e-05 1.00542951e-04
#  4.03614540e-05 4.09542517e-05 5.49391552e-05 1.49438463e-04
#  1.49857966e-04 3.13483142e-05 2.74867798e-05 2.62325448e-05
#  2.92331388e-05 1.86201905e-05 1.83542270e-05 3.51598101e-05
#  7.79171023e-05 6.69114161e-05 2.76081446e-05 5.80637716e-05
#  2.77168820e-05 3.59283767e-05 2.78203661e-05 6.27572372e-05
#  2.98061750e-05 1.26119057e-05 3.31663468e-05 2.18562927e-05
#  1.75902533e-05 1.39576277e-05 5.52899037e-05 5.51917183e-05
#  6.62426246e-05 4.68521175e-05 4.25347098e-05 1.26638944e-04
#  5.72240169e-05 5.22688679e-05 9.91538036e-05 1.63550756e-03
#  6.87133172e-04 1.30524364e-04 1.97066329e-05 3.41714040e-05
#  4.34543654e-05 4.06649524e-05 2.09149584e-05 3.51090202e-05
#  1.92779597e-04 2.61242792e-04 3.23426066e-05 6.93371621e-05
#  5.63447938e-05 1.07168191e-04 3.07296541e-05 1.02865881e-04
#  7.44727949e-05 3.36475023e-05 2.83560039e-05 3.02133103e-05
#  3.02848475e-05 3.07438713e-05 2.97606748e-05 4.61508971e-05
#  1.31164197e-04 1.94267966e-04 5.06518263e-05 4.31490247e-04
#  9.90583067e-05 2.39259010e-04 1.19494325e-04 2.05498259e-03
#  3.02101125e-05 2.67004634e-05 1.09946859e-05 2.15768850e-05
#  1.76692211e-05 1.71456031e-05 2.06846144e-05 5.01856703e-05
#  6.37238627e-05 1.03619313e-04 2.92355362e-05 6.88532382e-05
#  4.47849889e-05 9.86192026e-05 4.92852159e-05 5.60530694e-04
#  2.88738520e-05 1.95758566e-05 2.75411458e-05 2.85222213e-05
#  2.48070119e-05 3.36913326e-05 6.35772958e-05 2.70350429e-04
#  9.32910480e-05 1.11534267e-04 8.24092058e-05 1.36461155e-03
#  1.44466976e-04 5.62415284e-04 7.55211164e-04 2.06795651e-02
#  2.06953492e-02 3.76511191e-04 4.62848519e-04 3.27417365e-05
#  1.07553345e-03 3.72528630e-05 7.46441947e-05 2.64780410e-05
#  2.25227093e-04 5.56738923e-05 1.77555867e-05 1.25065553e-05
#  4.23450729e-05 1.89729453e-05 1.11815707e-05 1.54643440e-05
#  5.77043451e-04 2.63489783e-05 7.71645209e-05 2.09503105e-05
#  6.30586001e-05 1.18478647e-05 3.71258684e-05 2.17090583e-05
#  7.14913622e-05 2.41845792e-05 3.71211936e-05 1.67227772e-05
#  3.43976790e-05 2.01561143e-05 3.24614412e-05 3.86668944e-05
#  1.52875902e-03 4.64473596e-05 8.83825705e-05 2.72932866e-05
#  2.81616434e-04 3.70172711e-05 9.97622119e-05 6.47548150e-05
#  8.58799249e-05 3.80550919e-05 2.11894530e-05 1.75698351e-05
#  5.61822853e-05 3.83052211e-05 3.36084486e-05 9.03096225e-05
#  9.39180682e-05 2.09482732e-05 8.41759320e-05 2.41092130e-05
#  1.48298248e-04 1.84827841e-05 2.91731529e-04 1.57156595e-04
#  1.00559162e-04 3.24594585e-05 7.26037033e-05 7.89261903e-05
#  1.01961385e-04 5.44932664e-05 3.86498665e-04 1.25914917e-03
#  1.63790630e-03 7.66626690e-05 4.95949098e-05 2.11962870e-05
#  1.45366925e-04 3.23098975e-05 2.50938610e-05 2.17951019e-05
#  9.94375805e-05 4.56276321e-05 2.10388043e-05 1.31553888e-05
#  5.50112381e-05 3.30975963e-05 1.72506989e-05 2.89824056e-05
#  7.14276539e-05 1.31651032e-05 3.20339677e-05 1.23155178e-05
#  4.88425794e-05 1.79128692e-05 3.96046489e-05 2.82540823e-05
#  9.91403795e-05 3.39968356e-05 5.62444075e-05 3.42616222e-05
#  9.00051818e-05 6.50953662e-05 7.78740286e-05 3.56128992e-04
#  1.51756380e-04 2.51838082e-05 2.52909758e-05 1.91389499e-05
#  1.32640533e-04 4.42625606e-05 1.00397345e-04 6.01307765e-05
#  8.08239565e-05 3.29348877e-05 2.88097126e-05 2.18532296e-05
#  1.23206759e-04 7.75289955e-05 8.97240461e-05 3.34485492e-04
#  4.66301972e-05 1.88591730e-05 4.44466750e-05 2.35420412e-05
#  1.53562913e-04 5.26637523e-05 2.54556770e-04 3.36285826e-04
#  1.31610141e-04 5.74330516e-05 8.50662473e-05 3.20882333e-04
#  5.32967329e-04 5.77683561e-04 1.57102745e-03 9.88302473e-03
#  9.37988923e-04 5.47917807e-05 5.78430008e-05 3.79537632e-05
#  5.15919055e-05 1.90577921e-05 3.20012696e-05 2.36096439e-05
#  6.02722757e-05 4.78423353e-05 1.75979385e-05 2.96457602e-05
#  1.99745045e-05 1.61552234e-05 2.22246526e-05 2.69026568e-05
#  7.68774407e-05 2.57196007e-05 5.98880397e-05 4.44805119e-05
#  3.49330221e-05 1.20777813e-05 4.93741645e-05 4.78217189e-05
#  8.11450736e-05 3.58801044e-05 5.22268710e-05 1.18400196e-04
#  2.87709991e-05 2.73871228e-05 7.45377984e-05 4.19787364e-04
#  1.02610167e-04 4.12036170e-05 6.62025268e-05 4.32257802e-05
#  6.16731631e-05 2.18426667e-05 7.16713475e-05 6.49176654e-05
#  7.15082715e-05 4.45360238e-05 3.90379428e-05 4.38018324e-05
#  4.35377333e-05 3.31724841e-05 3.66587483e-05 2.85480142e-04
#  7.17761868e-05 2.44589355e-05 1.16867508e-04 1.25054008e-04
#  8.18162443e-05 3.36066842e-05 3.12655699e-04 1.18972454e-03
#  1.27898864e-04 7.87346726e-05 2.34510895e-04 1.61029305e-03
#  1.49974090e-04 3.82882310e-04 1.44054834e-03 2.07003895e-02
#  3.10105504e-04 8.70902004e-05 3.84356972e-05 4.45765581e-05
#  6.36468685e-05 4.12053487e-05 4.39503601e-05 5.69813237e-05
#  1.56121663e-04 1.29223030e-04 3.75823765e-05 6.32151859e-05
#  7.85597877e-05 1.16565592e-04 3.86684769e-05 2.54707964e-04
#  8.36617110e-05 3.23957865e-05 6.05446839e-05 7.84644144e-05
#  6.02172986e-05 3.72593640e-05 1.15498937e-04 2.88359559e-04
#  2.67915777e-04 3.86948959e-04 1.32251036e-04 1.80687744e-03
#  1.45389655e-04 8.25435854e-04 5.92321507e-04 9.84319765e-03
#  5.57928252e-05 6.42395680e-05 4.57472670e-05 5.73948382e-05
#  9.75290313e-05 5.30379948e-05 1.47528728e-04 4.32336936e-04
#  1.34828457e-04 1.46167673e-04 6.38435013e-05 2.30793550e-04
#  3.01259599e-04 6.97263982e-04 3.61981598e-04 5.44475159e-03
#  7.78912217e-05 5.46774245e-05 1.03588791e-04 3.25293833e-04
#  1.65699545e-04 1.86015430e-04 1.42708828e-03 1.00539103e-02
#  3.86436615e-04 1.65518792e-03 1.30431179e-03 2.06660219e-02
#  1.99318188e-03 9.83866304e-03 2.06114538e-02 3.31309259e-01]
# [3.31313699e-01 2.06826348e-02 9.94949322e-03 1.71240827e-03
#  2.06826348e-02 1.35074696e-03 1.71240827e-03 4.10438020e-04
#  9.94949322e-03 1.71240827e-03 3.16181628e-04 1.88736652e-04
#  6.31323492e-04 1.21927864e-04 6.09389463e-05 6.81181191e-05
#  5.44604240e-03 3.55930650e-04 3.39340884e-04 7.90376216e-05
#  3.55930650e-04 2.65514700e-05 7.90376216e-05 3.54549775e-05
#  3.39340884e-04 7.90376216e-05 3.05453286e-05 5.04999152e-05
#  2.52571117e-05 1.00767411e-05 1.38404075e-05 6.81181191e-05
#  9.94949322e-03 6.31323492e-04 3.16181628e-04 6.09389463e-05
#  1.71240827e-03 1.21927864e-04 1.88736652e-04 6.81181191e-05
#  3.06387723e-04 5.75983649e-05 1.13676333e-05 1.09417588e-05
#  5.75983649e-05 1.65706133e-05 1.09417588e-05 3.54549775e-05
#  3.39340884e-04 2.52571117e-05 3.05453286e-05 1.38404075e-05
#  7.90376216e-05 1.00767411e-05 5.04999152e-05 6.81181191e-05
#  2.83374702e-05 1.22730298e-05 6.79290952e-06 3.69958761e-05
#  1.22730298e-05 1.85113677e-05 3.69958761e-05 4.10438020e-04
#  2.06826348e-02 1.35074696e-03 6.31323492e-04 1.21927864e-04
#  1.30537956e-03 9.22902473e-05 1.15495088e-04 3.69958761e-05
#  1.71240827e-03 4.10438020e-04 6.09389463e-05 6.81181191e-05
#  1.15495088e-04 3.69958761e-05 1.65863257e-05 5.04999152e-05
#  3.55930650e-04 2.65514700e-05 2.52571117e-05 1.00767411e-05
#  2.49531877e-05 2.73124647e-06 8.78071478e-06 1.09417588e-05
#  7.90376216e-05 3.54549775e-05 1.38404075e-05 6.81181191e-05
#  8.78071478e-06 1.09417588e-05 1.71951688e-05 1.88736652e-04
#  6.31323492e-04 4.35558286e-05 2.15226701e-05 5.85949192e-06
#  1.15495088e-04 1.06592561e-05 1.71951688e-05 1.38404075e-05
#  5.75983649e-05 1.85113677e-05 3.33479852e-06 1.00767411e-05
#  1.49702710e-05 1.22730298e-05 8.78071478e-06 7.90376216e-05
#  2.52571117e-05 3.00654642e-06 4.00434647e-06 5.85949192e-06
#  8.78071478e-06 3.33479852e-06 1.65863257e-05 6.09389463e-05
#  1.22730298e-05 1.65706133e-05 1.06592561e-05 1.21927864e-04
#  1.49702710e-05 5.75983649e-05 1.15495088e-04 1.71240827e-03
#  9.94949322e-03 6.31323492e-04 3.06387723e-04 5.75983649e-05
#  6.31323492e-04 4.35558286e-05 5.75983649e-05 1.85113677e-05
#  3.16181628e-04 6.09389463e-05 1.13676333e-05 1.09417588e-05
#  2.15226701e-05 5.85949192e-06 3.33479852e-06 1.00767411e-05
#  3.39340884e-04 2.52571117e-05 2.83374702e-05 1.22730298e-05
#  2.52571117e-05 3.00654642e-06 1.22730298e-05 1.65706133e-05
#  3.05453286e-05 1.38404075e-05 6.79290952e-06 3.69958761e-05
#  4.00434647e-06 5.85949192e-06 1.06592561e-05 1.21927864e-04
#  3.16181628e-04 2.15226701e-05 1.13676333e-05 3.33479852e-06
#  6.09389463e-05 5.85949192e-06 1.09417588e-05 1.00767411e-05
#  1.13676333e-05 3.33479852e-06 7.85737200e-07 2.73124647e-06
#  3.33479852e-06 3.00654642e-06 2.73124647e-06 2.65514700e-05
#  3.05453286e-05 4.00434647e-06 6.79290952e-06 1.06592561e-05
#  1.38404075e-05 5.85949192e-06 3.69958761e-05 1.21927864e-04
#  6.79290952e-06 1.06592561e-05 7.78999492e-06 9.22902473e-05
#  1.06592561e-05 4.35558286e-05 9.22902473e-05 1.35074696e-03
#  1.71240827e-03 1.21927864e-04 5.75983649e-05 1.65706133e-05
#  1.15495088e-04 1.06592561e-05 1.49702710e-05 1.22730298e-05
#  1.88736652e-04 6.81181191e-05 1.09417588e-05 3.54549775e-05
#  1.71951688e-05 1.38404075e-05 8.78071478e-06 7.90376216e-05
#  7.90376216e-05 1.00767411e-05 1.22730298e-05 1.85113677e-05
#  8.78071478e-06 3.33479852e-06 1.49702710e-05 5.75983649e-05
#  5.04999152e-05 6.81181191e-05 3.69958761e-05 4.10438020e-04
#  1.65863257e-05 6.09389463e-05 1.15495088e-04 1.71240827e-03
#  6.09389463e-05 5.85949192e-06 3.33479852e-06 3.00654642e-06
#  1.65863257e-05 4.00434647e-06 8.78071478e-06 2.52571117e-05
#  1.09417588e-05 1.00767411e-05 2.73124647e-06 2.65514700e-05
#  8.78071478e-06 2.52571117e-05 2.49531877e-05 3.55930650e-04
#  1.38404075e-05 5.85949192e-06 1.06592561e-05 4.35558286e-05
#  1.71951688e-05 2.15226701e-05 1.15495088e-04 6.31323492e-04
#  3.69958761e-05 1.21927864e-04 9.22902473e-05 1.35074696e-03
#  1.15495088e-04 6.31323492e-04 1.30537956e-03 2.06826348e-02
#  2.06826348e-02 1.30537956e-03 6.31323492e-04 1.15495088e-04
#  1.35074696e-03 9.22902473e-05 1.21927864e-04 3.69958761e-05
#  6.31323492e-04 1.15495088e-04 2.15226701e-05 1.71951688e-05
#  4.35558286e-05 1.06592561e-05 5.85949192e-06 1.38404075e-05
#  3.55930650e-04 2.49531877e-05 2.52571117e-05 8.78071478e-06
#  2.65514700e-05 2.73124647e-06 1.00767411e-05 1.09417588e-05
#  2.52571117e-05 8.78071478e-06 4.00434647e-06 1.65863257e-05
#  3.00654642e-06 3.33479852e-06 5.85949192e-06 6.09389463e-05
#  1.71240827e-03 1.15495088e-04 6.09389463e-05 1.65863257e-05
#  4.10438020e-04 3.69958761e-05 6.81181191e-05 5.04999152e-05
#  5.75983649e-05 1.49702710e-05 3.33479852e-06 8.78071478e-06
#  1.85113677e-05 1.22730298e-05 1.00767411e-05 7.90376216e-05
#  7.90376216e-05 8.78071478e-06 1.38404075e-05 1.71951688e-05
#  3.54549775e-05 1.09417588e-05 6.81181191e-05 1.88736652e-04
#  1.22730298e-05 1.49702710e-05 1.06592561e-05 1.15495088e-04
#  1.65706133e-05 5.75983649e-05 1.21927864e-04 1.71240827e-03
#  1.35074696e-03 9.22902473e-05 4.35558286e-05 1.06592561e-05
#  9.22902473e-05 7.78999492e-06 1.06592561e-05 6.79290952e-06
#  1.21927864e-04 3.69958761e-05 5.85949192e-06 1.38404075e-05
#  1.06592561e-05 6.79290952e-06 4.00434647e-06 3.05453286e-05
#  2.65514700e-05 2.73124647e-06 3.00654642e-06 3.33479852e-06
#  2.73124647e-06 7.85737200e-07 3.33479852e-06 1.13676333e-05
#  1.00767411e-05 1.09417588e-05 5.85949192e-06 6.09389463e-05
#  3.33479852e-06 1.13676333e-05 2.15226701e-05 3.16181628e-04
#  1.21927864e-04 1.06592561e-05 5.85949192e-06 4.00434647e-06
#  3.69958761e-05 6.79290952e-06 1.38404075e-05 3.05453286e-05
#  1.65706133e-05 1.22730298e-05 3.00654642e-06 2.52571117e-05
#  1.22730298e-05 2.83374702e-05 2.52571117e-05 3.39340884e-04
#  1.00767411e-05 3.33479852e-06 5.85949192e-06 2.15226701e-05
#  1.09417588e-05 1.13676333e-05 6.09389463e-05 3.16181628e-04
#  1.85113677e-05 5.75983649e-05 4.35558286e-05 6.31323492e-04
#  5.75983649e-05 3.06387723e-04 6.31323492e-04 9.94949322e-03
#  1.71240827e-03 1.15495088e-04 5.75983649e-05 1.49702710e-05
#  1.21927864e-04 1.06592561e-05 1.65706133e-05 1.22730298e-05
#  6.09389463e-05 1.65863257e-05 3.33479852e-06 8.78071478e-06
#  5.85949192e-06 4.00434647e-06 3.00654642e-06 2.52571117e-05
#  7.90376216e-05 8.78071478e-06 1.22730298e-05 1.49702710e-05
#  1.00767411e-05 3.33479852e-06 1.85113677e-05 5.75983649e-05
#  1.38404075e-05 1.71951688e-05 1.06592561e-05 1.15495088e-04
#  5.85949192e-06 2.15226701e-05 4.35558286e-05 6.31323492e-04
#  1.88736652e-04 1.71951688e-05 1.09417588e-05 8.78071478e-06
#  6.81181191e-05 1.38404075e-05 3.54549775e-05 7.90376216e-05
#  1.09417588e-05 8.78071478e-06 2.73124647e-06 2.49531877e-05
#  1.00767411e-05 2.52571117e-05 2.65514700e-05 3.55930650e-04
#  5.04999152e-05 1.65863257e-05 3.69958761e-05 1.15495088e-04
#  6.81181191e-05 6.09389463e-05 4.10438020e-04 1.71240827e-03
#  3.69958761e-05 1.15495088e-04 9.22902473e-05 1.30537956e-03
#  1.21927864e-04 6.31323492e-04 1.35074696e-03 2.06826348e-02
#  4.10438020e-04 3.69958761e-05 1.85113677e-05 1.22730298e-05
#  3.69958761e-05 6.79290952e-06 1.22730298e-05 2.83374702e-05
#  6.81181191e-05 5.04999152e-05 1.00767411e-05 7.90376216e-05
#  1.38404075e-05 3.05453286e-05 2.52571117e-05 3.39340884e-04
#  3.54549775e-05 1.09417588e-05 1.65706133e-05 5.75983649e-05
#  1.09417588e-05 1.13676333e-05 5.75983649e-05 3.06387723e-04
#  6.81181191e-05 1.88736652e-04 1.21927864e-04 1.71240827e-03
#  6.09389463e-05 3.16181628e-04 6.31323492e-04 9.94949322e-03
#  6.81181191e-05 1.38404075e-05 1.00767411e-05 2.52571117e-05
#  5.04999152e-05 3.05453286e-05 7.90376216e-05 3.39340884e-04
#  3.54549775e-05 7.90376216e-05 2.65514700e-05 3.55930650e-04
#  7.90376216e-05 3.39340884e-04 3.55930650e-04 5.44604240e-03
#  6.81181191e-05 6.09389463e-05 1.21927864e-04 6.31323492e-04
#  1.88736652e-04 3.16181628e-04 1.71240827e-03 9.94949322e-03
#  4.10438020e-04 1.71240827e-03 1.35074696e-03 2.06826348e-02
#  1.71240827e-03 9.94949322e-03 2.06826348e-02 3.31313699e-01]

# %%
import matplotlib.pyplot as plt

fig, axs = plt.subplots(3, 1, figsize=(10, 12), sharex=True)

axs[0].plot(loss_log["total"], color='blue', linestyle='-', marker='o', markersize=3)
axs[0].set_title("Total Loss")
axs[0].set_ylabel("Loss")
axs[0].grid(True)

axs[1].plot(loss_log["mse"], color='green', linestyle='-', marker='o', markersize=3)
axs[1].set_title("MSE Loss")
axs[1].set_ylabel("Loss")
axs[1].grid(True)

axs[2].plot(loss_log["phys"], color='red', linestyle='-', marker='o', markersize=3)
axs[2].set_title("Physics-Informed Loss")
axs[2].set_xlabel("Epoch")
axs[2].set_ylabel("Loss")
axs[2].grid(True)

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import r2_score
import torch.nn.functional as F

model.eval()
with torch.no_grad():
    y_pred = model(X)
    y_pred_norm = y_pred / torch.sum(y_pred)

    y_true_np = y_true.numpy().flatten()
    y_pred_np = y_pred_norm.numpy().flatten()

kl_div = F.kl_div(torch.log(y_pred_norm + 1e-8), y_true, reduction='batchmean')  # Add epsilon for safety
print(f"KL Divergence: {kl_div.item():.6f}")

r2 = r2_score(y_true_np, y_pred_np)
print(f"R² Score: {r2:.6f}")
# Out:
# KL Divergence: 0.000028
# R² Score: 0.999949

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))

plt.plot(y_true.numpy(), label="True ψ²", color='blue', linestyle='--')

plt.plot(y_pred_norm.detach().numpy(), label="Predicted ψ²", color='red', linestyle='-.')

plt.xlabel("Sample Index")
plt.ylabel("ψ²")
plt.title("True ψ² and Predicted ψ² vs Sample Index")
plt.grid(True)
plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

x_range = slice(100, 900)
y_true_range = y_true.numpy()[x_range]
y_pred_range = y_pred_norm.detach().numpy()[x_range]

plt.figure(figsize=(10, 6))

plt.plot(y_true_range, label="True ψ²", color='blue', linestyle='--')

plt.plot(y_pred_range, label="Predicted ψ²", color='red', linestyle='-.')

plt.xlabel("Sample Index")
plt.ylabel("ψ²")
plt.title("True ψ² and Predicted ψ² vs Sample Index (x=100 to x=900)")
plt.grid(True)

plt.xlim(100, 900)

plt.legend()

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 6))
plt.scatter(y_true_np, y_pred_np, alpha=0.6, color='royalblue', edgecolor='k')
plt.plot([y_true_np.min(), y_true_np.max()], [y_true_np.min(), y_true_np.max()], 'r--', label='Ideal: y = x')
plt.xlabel("True $\psi^2$")
plt.ylabel("Predicted $\psi^2$")
plt.title("True vs Predicted $\psi^2$")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
